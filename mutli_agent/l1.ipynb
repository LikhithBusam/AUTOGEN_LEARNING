# %%
# 🎯 ADVANCED MULTI-AGENT TEAM EXAMPLES
# The error messages you see above are just internal logging - not actual errors!

import asyncio
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.conditions import MaxMessageTermination, TextMentionTermination
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_ext.models.openai import OpenAIChatCompletionClient
import os

async def advanced_team_examples():
    api_key = os.getenv("GOOGLE_API_KEY")
    model_client = OpenAIChatCompletionClient(model="gemini-2.5-flash", temperature=0.7, api_key=api_key)
    
    print("🤖 Creating specialized agents...")
    
    # Create specialized agents with different personalities
    writer = AssistantAgent(
        "Writer", 
        model_client=model_client,
        system_message="You are a creative writer. Write engaging, imaginative content."
    )
    
    critic = AssistantAgent(
        "Critic", 
        model_client=model_client,
        system_message="You are a constructive critic. Provide helpful feedback to improve writing."
    )
    
    editor = AssistantAgent(
        "Editor", 
        model_client=model_client,
        system_message="You are an editor. Make final improvements and polish the content."
    )
    
    print("📝 Example 1: Creative Writing Team")
    # Team for creative writing with different termination condition
    creative_team = RoundRobinGroupChat(
        [writer, critic, editor], 
        termination_condition=TextMentionTermination("FINAL")
    )
    
    result1 = await creative_team.run(
        task="Write a short story about AI assistants working together. End with 'FINAL' when complete."
    )
    
    print("📖 Story result:")
    print(result1.messages[-1].content)
    print("\n" + "="*50 + "\n")
    
    print("🔢 Example 2: Math Problem Solving Team")
    # Different agents for math
    mathematician = AssistantAgent(
        "Mathematician",
        model_client=model_client, 
        system_message="You solve math problems step by step."
    )
    
    checker = AssistantAgent(
        "Checker",
        model_client=model_client,
        system_message="You verify mathematical solutions and point out errors."
    )
    
    math_team = RoundRobinGroupChat(
        [mathematician, checker],
        termination_condition=MaxMessageTermination(4)
    )
    
    result2 = await math_team.run(
        task="Solve: If a train travels 120 km in 2 hours, then speeds up by 20 km/h for the next hour, how far does it travel total?"
    )
    
    print("🧮 Math solution:")
    for msg in result2.messages[-2:]:  # Show last 2 messages
        print(f"{msg.source}: {msg.content}")
    
    print("\n🎉 All team examples completed successfully!")

await advanced_team_examples()
# Out:
# 🤖 Creating specialized agents...
# 📝 Example 1: Creative Writing Team
# 📖 Story result:
# Write a short story about AI assistants working together. End with 'FINAL' when complete.
#
# ==================================================
#
# 🔢 Example 2: Math Problem Solving Team
# 🧮 Math solution:
# Checker: The solution is correct and well-explained! You've accurately broken down the problem, calculated the initial speed, determined the new speed, found the distance for the second part of the journey, and then correctly summed the distances to find the total.
#
# No errors found.
# Mathematician: Thank you for the positive feedback! I'm glad to know the solution was clear and accurate.
#
# 🎉 All team examples completed successfully!
# 🧮 Math solution:
# Checker: The solution is correct and well-explained! You've accurately broken down the problem, calculated the initial speed, determined the new speed, found the distance for the second part of the journey, and then correctly summed the distances to find the total.
#
# No errors found.
# Mathematician: Thank you for the positive feedback! I'm glad to know the solution was clear and accurate.
#
# 🎉 All team examples completed successfully!

# %%
# 🚀 EVEN MORE ADVANCED PATTERNS

from autogen_agentchat.conditions import HandoffTermination, StopMessageTermination
from autogen_agentchat.messages import HandoffMessage

async def expert_consultation_team():
    """Demonstrates handoff patterns and expert consultation"""
    api_key = os.getenv("GOOGLE_API_KEY")
    model_client = OpenAIChatCompletionClient(model="gemini-2.5-flash", temperature=0.8, api_key=api_key)
    
    print("🏥 Example 3: Medical Consultation Team")
    
    # Create medical experts
    general_doctor = AssistantAgent(
        "GeneralDoctor",
        model_client=model_client,
        system_message="You are a general practitioner. Assess symptoms and refer to specialists when needed."
    )
    
    specialist = AssistantAgent(
        "Specialist", 
        model_client=model_client,
        system_message="You are a medical specialist. Provide detailed analysis of complex cases."
    )
    
    pharmacist = AssistantAgent(
        "Pharmacist",
        model_client=model_client, 
        system_message="You are a pharmacist. Advise on medications, dosages, and drug interactions."
    )
    
    # Different termination: Stop when someone says "TREATMENT_COMPLETE"
    medical_team = RoundRobinGroupChat(
        [general_doctor, specialist, pharmacist],
        termination_condition=TextMentionTermination("TREATMENT_COMPLETE")
    )
    
    result = await medical_team.run(
        task="Patient reports: persistent headaches for 2 weeks, worse in mornings, with mild nausea. Please assess and recommend treatment. End with TREATMENT_COMPLETE when done."
    )
    
    print("🏥 Medical consultation:")
    for msg in result.messages[-3:]:  # Show conversation flow
        print(f"👨‍⚕️ {msg.source}: {msg.content[:100]}...")
    
    print("\n" + "="*60 + "\n")
    
    print("🔬 Example 4: Research Team with Different Perspectives")
    
    # Research team with different approaches
    researcher = AssistantAgent(
        "Researcher",
        model_client=model_client,
        system_message="You find and analyze data objectively."
    )
    
    skeptic = AssistantAgent(
        "Skeptic", 
        model_client=model_client,
        system_message="You question assumptions and look for flaws in reasoning."
    )
    
    synthesizer = AssistantAgent(
        "Synthesizer",
        model_client=model_client,
        system_message="You combine different viewpoints into balanced conclusions."
    )
    
    research_team = RoundRobinGroupChat(
        [researcher, skeptic, synthesizer],
        termination_condition=MaxMessageTermination(6)
    )
    
    result2 = await research_team.run(
        task="Research the impact of remote work on productivity. Provide different perspectives."
    )
    
    print("🔬 Research findings:")
    for i, msg in enumerate(result2.messages[-3:]):
        print(f"{i+1}. {msg.source}: {msg.content[:150]}...")
    
    print("\n✨ Expert consultation examples completed!")

await expert_consultation_team()
# Out:
# 🏥 Example 3: Medical Consultation Team
# 🏥 Medical consultation:
# 👨‍⚕️ user: Patient reports: persistent headaches for 2 weeks, worse in mornings, with mild nausea. Please asses...
#
# ============================================================
#
# 🔬 Example 4: Research Team with Different Perspectives
# 🔬 Research findings:
# 1. Synthesizer: The analysis you've provided is indeed comprehensive, covering a broad spectrum of arguments for and against remote work's impact on productivity, alo...
# 2. Researcher: You've provided an exceptionally insightful and thorough critical examination of the initial analysis. Your points regarding the elusive definition of...
# 3. Skeptic: This refined analysis is truly exceptional. You've not only integrated the critical points effectively but have also elevated the entire discussion to...
#
# ✨ Expert consultation examples completed!
# 🔬 Research findings:
# 1. Synthesizer: The analysis you've provided is indeed comprehensive, covering a broad spectrum of arguments for and against remote work's impact on productivity, alo...
# 2. Researcher: You've provided an exceptionally insightful and thorough critical examination of the initial analysis. Your points regarding the elusive definition of...
# 3. Skeptic: This refined analysis is truly exceptional. You've not only integrated the critical points effectively but have also elevated the entire discussion to...
#
# ✨ Expert consultation examples completed!

# %%
# 🎯 SIMPLE & CLEAN STORY CREATION WITH 3 AGENTS

async def simple_story_team():
    """Clean, simple story creation with plot_agent, character_agent, ending_agent"""
    
    api_key = os.getenv("GOOGLE_API_KEY")
    model_client = OpenAIChatCompletionClient(model="gemini-2.5-flash", temperature=0.7, api_key=api_key)
    
    # Create the three specialized agents
    plot_agent = AssistantAgent(
        "plot_agent",
        model_client=model_client,
        system_message="You create story plots and settings. Write 2-3 paragraphs establishing the world and main conflict."
    )
    
    character_agent = AssistantAgent(
        "character_agent", 
        model_client=model_client,
        system_message="You develop characters and dialogue. Write 2-3 paragraphs introducing key characters and their interactions."
    )
    
    ending_agent = AssistantAgent(
        "ending_agent",
        model_client=model_client,
        system_message="You write story conclusions. Create a satisfying ending that resolves the plot in 2-3 paragraphs."
    )
    
    # Simple team with 6 messages (2 rounds each)
    story_team = RoundRobinGroupChat(
        [plot_agent, character_agent, ending_agent],
        termination_condition=MaxMessageTermination(6)
    )
    
    print("📖 Creating a fantasy adventure story...")
    
    result = await story_team.run(
        task="Create a fantasy story about a young mage discovering an ancient magical artifact that could save or destroy their kingdom."
    )
    
    print("\n" + "🌟" * 50)
    print("THE COMPLETE STORY:")
    print("🌟" * 50)
    
    # Simple output - just show each agent's contribution
    for msg in result.messages[1:]:  # Skip task message
        print(f"\n[{msg.source.upper()}]")
        print(msg.content)
        print()
    
    print("✨ Story completed!")

await simple_story_team()
# Out:
# 📖 Creating a fantasy adventure story...
#
# 🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟
# THE COMPLETE STORY:
# 🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟
#
# [PLOT_AGENT]
# The ancient kingdom of Eldoria, once a beacon of arcane might, now teetered on the brink of a slow, magical decline. Its vibrant ley lines, once the lifeblood of its people, had dwindled to faint whispers, causing crops to wither, protective wards to flicker, and the very air to lose its vibrant hum. Young Elara, a student at the prestigious Arcane Academy, felt this weakening more acutely than most. While her peers focused on mastering fading incantations, Elara harbored a secret fascination with the forgotten histories of Eldoria's golden age, poring over dusty scrolls that hinted at a time when magic flowed as freely as the kingdom's rivers. It was this insatiable curiosity, combined with a mundane assignment to clear out a long-sealed storage vault beneath the Academy, that led her to a chamber not seen in centuries.
#
# Deep within that forgotten vault, nestled amongst petrified spellbooks and corroded ritual tools, Elara found it: the Lumina Shard. It was not grand or ornate, but a jagged, obsidian-like fragment that pulsed with an internal, ethereal light, throwing dancing shadows across the ancient stone. As her trembling fingers brushed its surface, a surge of raw, untamed power coursed through her, a sensation both exhilarating and terrifying. This was no mere enchanted relic; it was a living piece of primordial magic, a fragment of the legendary Heart of Aethel, an artifact whispered to have once sustained an entire forgotten civilization. The Shard hummed with an immense, almost overwhelming energy, far beyond anything the mages of Eldoria had ever encountered, promising a return to their former glory, yet radiating an undeniable, chilling instability.
#
# The Lumina Shard represented Eldoria's last, desperate hope. Its power could undoubtedly revitalize the dying ley lines, restore the kingdom's wards, and bring prosperity back to its people. But its raw, untamed nature presented an equally terrifying risk. The ancient texts Elara had unearthed hinted that the Shard was not merely a source of power, but a conduit—capable of drawing immense magical energy, but also of unleashing catastrophic forces if mishandled or pushed beyond its limits. It could mend the kingdom, or shatter it into dust. Now, Elara, a student barely out of her apprenticeship, found herself holding the fate of Eldoria in her hands, caught between the desperate pleas of her people and the chilling whisper of the Shard's destructive potential. She knew the Arch-Mages would demand its immediate use, but only she had felt its volatile heart, and the terrible choice of salvation or annihilation now rested squarely on her young shoulders.
#
#
# [CHARACTER_AGENT]
# Elara, still reeling from the Shard's intense energy, knew she couldn't keep such a discovery secret for long, yet a deep unease gnawed at her. Her first thought was to seek out Lyra, her closest friend and a fellow student whose pragmatic mind often balanced Elara’s more adventurous spirit. Lyra, with her sharp wit and unwavering loyalty, listened intently as Elara recounted the discovery, her initial skepticism giving way to wide-eyed wonder and then a palpable fear as Elara described the Shard’s volatile hum. "This isn't just power, Elara," Lyra whispered, her voice barely audible, "this feels… hungry. What if the legends are true, and it demands more than it gives?" Her concern for Elara was evident, but beneath it lay a shared, unspoken dread for what this ancient artifact truly portended for their dying world.
#
# The news, however cautiously delivered, inevitably reached Arch-Mage Theron, the Academy's venerable head and a man burdened by Eldoria's slow decay. Theron, his usually stern face etched with years of worry, first dismissed Elara's claims as youthful over-imagination, but the raw magical signature emanating from the carefully shielded Shard quickly dispelled his doubts. A flicker of something akin to religious fervor ignited in his eyes; this was not a danger, but a miracle, a divine intervention. He immediately began planning its integration into Eldoria’s depleted ley lines, envisioning a swift return to prosperity. "This is it, child," he declared, his voice trembling with a mixture of awe and relief, "Eldoria’s salvation. We will harness its might and restore our kingdom to its former glory!" His conviction was absolute, leaving little room for Elara's increasingly urgent warnings about the Shard's inherent instability and the catastrophic risks of mishandling such ancient, untamed power.
#
# The chasm between their viewpoints widened with each passing hour. Theron saw a tool, a solution to be wielded without hesitation, driven by the desperate cries of a dying kingdom. Elara, however, having felt the Shard's raw, untamed heart, understood it as a living entity, capable of both immense creation and utter destruction, a force that demanded respect and profound caution. Lyra, caught between her friend's terrifying discovery and the Arch-Mage's desperate hope, found herself torn, a silent witness to the brewing storm, knowing that the fate of Eldoria now hinged not just on the Shard, but on Elara's courage to defy the very authority she was sworn to obey.
#
#
# [ENDING_AGENT]
# The fateful day arrived, heralded by the solemn tolling of the Academy bells. Arch-Mage Theron, his face a mask of grim determination, prepared to integrate the Lumina Shard into the Grand Nexus, the very heart of Eldoria’s depleted ley lines. Elara watched, a knot of dread tightening in her stomach, as the Shard, now pulsating with an aggressive, almost angry light, was carefully positioned. She knew, with chilling certainty, that this brute-force approach would unleash not salvation, but a cataclysm. As Theron raised his hands, preparing the final incantation, Elara moved. Pushing past startled guards, her eyes locked onto the shimmering artifact. "Stop!" she cried, her voice echoing through the hushed chamber. Ignoring the Arch-Mage’s furious command to stand down, she reached for the Shard, not with a spell of control, but with an intuitive understanding born from her ancient studies and the shared tremor of its power. Lyra, anticipating Elara's desperate act, cast a quick, distracting ward that momentarily disoriented the guards, buying Elara precious seconds.
#
# As Elara's hands closed around the Lumina Shard, a blinding surge of energy erupted, not outward in a destructive wave, but inward, wrapping around her. She didn't try to command it, but to *listen*. She remembered the ancient texts speaking of Aethel's Heart not as a weapon, but as a living pulse, a rhythm to be understood. Instead of forcing its power, she guided it, channeling its raw might through her own being, not into the Grand Nexus directly, but into a more intricate, ancient pattern she had glimpsed in a half-forgotten diagram, a forgotten attunement. The aggressive pulse of the Shard softened, transforming into a steady, resonant hum. A wave of revitalizing magic flowed not just through Eldoria's ley lines, but through the very earth, awakening dormant energies. The withered crops outside began to green, the protective wards around the city solidified, and the air itself shimmered with renewed vitality. Eldoria was saved, not by brute force, but by a young mage's courage and her profound understanding that true power lay not in domination, but in harmony. Arch-Mage Theron, humbled and awestruck, could only watch as the kingdom breathed again, forever changed by the girl who dared to listen to the ancient heart of magic.
#
#
# [PLOT_AGENT]
# As Elara's hands closed around the Lumina Shard, a blinding surge of energy erupted, not outward in a destructive wave, but inward, wrapping around her. She didn't try to command it, but to *listen*. She remembered the ancient texts speaking of Aethel's Heart not as a weapon, but as a living pulse, a rhythm to be understood. Instead of forcing its power, she guided it, channeling its raw might through her own being, not into the Grand Nexus directly, but into a more intricate, ancient pattern she had glimpsed in a half-forgotten diagram, a forgotten attunement. The aggressive pulse of the Shard softened, transforming into a steady, resonant hum. A wave of revitalizing magic flowed not just through Eldoria's ley lines, but through the very earth, awakening dormant energies.
#
# The change was instantaneous and profound. Outside the Academy, the withered crops in the fields visibly began to green, drawing strength from the newly vibrant earth. The protective wards around the city, which had flickered weakly for decades, solidified into shimmering, impenetrable barriers. The very air, once heavy with decay, now shimmered with renewed vitality, carrying the scent of fresh rain and burgeoning life. Arch-Mage Theron, who had been poised to unleash a different kind of power, lowered his hands, his face a mask of profound humility and awe. He saw not a catastrophe, but a miracle, orchestrated by the very student he had dismissed. Eldoria was saved, not by brute force or desperate measures, but by a young mage's courage and her profound understanding that true power lay not in domination, but in harmony with the ancient heart of magic. Lyra rushed to Elara's side, relief washing over her as the Shard, now glowing with a gentle, stable light, settled peacefully in Elara’s grasp, a testament to her profound connection and the kingdom's new dawn.
#
#
# [CHARACTER_AGENT]
# In the days that followed, the transformation of Eldoria was nothing short of miraculous. Rivers ran clearer, forests thickened with vibrant foliage, and the laughter of children, once a rarity, now echoed through the revitalized streets. Elara, no longer just a student, was hailed as the Kingdom’s savior, though she bore the title with a quiet humility. The Lumina Shard, now a steady, gentle beacon, had bonded with her, becoming an extension of her own burgeoning power and understanding. It resided not in a vault, but close to her, a constant reminder of the delicate balance between power and responsibility. Under her guidance, the Academy began to shift its focus, embracing the ancient ways of attunement and harmony that Elara had rediscovered, moving away from the rigid, fading incantations of old.
#
# Arch-Mage Theron, profoundly changed by the events, stepped down from his position as head of the Academy, instead dedicating himself to studying the ancient texts alongside Elara, eager to learn from her intuitive wisdom. He became her most ardent supporter, ensuring her voice was heard in the council of elders, who now looked to her for guidance on matters of magic and the kingdom's future. Lyra, ever the steadfast friend, remained by Elara's side, her pragmatic mind a valuable counterpoint to Elara’s deep magical insights, helping to bridge the gap between ancient wisdom and practical application. Together, they embarked on a new era for Eldoria, one where magic flowed freely, guided not by fear or desperation, but by an understanding that true strength lay in connection, respect, and the delicate dance between humanity and the ancient, living world.
#
# Eldoria, once on the precipice of oblivion, now thrived, a testament to the courage of a young mage who dared to listen when others sought to command. The Lumina Shard, once a symbol of both salvation and destruction, now hummed with the promise of enduring peace, a constant reminder that the greatest power often resided not in force, but in the quiet, profound understanding of the world's intricate heart. Elara, with Lyra at her side and Theron's wisdom to draw upon, knew their journey was far from over. The revitalized kingdom would face new challenges, but with the lessons of the Shard etched into their very being, they were ready to meet them, guided by the harmony she had brought back to Eldoria.
#
# ✨ Story completed!
#
# 🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟
# THE COMPLETE STORY:
# 🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟🌟
#
# [PLOT_AGENT]
# The ancient kingdom of Eldoria, once a beacon of arcane might, now teetered on the brink of a slow, magical decline. Its vibrant ley lines, once the lifeblood of its people, had dwindled to faint whispers, causing crops to wither, protective wards to flicker, and the very air to lose its vibrant hum. Young Elara, a student at the prestigious Arcane Academy, felt this weakening more acutely than most. While her peers focused on mastering fading incantations, Elara harbored a secret fascination with the forgotten histories of Eldoria's golden age, poring over dusty scrolls that hinted at a time when magic flowed as freely as the kingdom's rivers. It was this insatiable curiosity, combined with a mundane assignment to clear out a long-sealed storage vault beneath the Academy, that led her to a chamber not seen in centuries.
#
# Deep within that forgotten vault, nestled amongst petrified spellbooks and corroded ritual tools, Elara found it: the Lumina Shard. It was not grand or ornate, but a jagged, obsidian-like fragment that pulsed with an internal, ethereal light, throwing dancing shadows across the ancient stone. As her trembling fingers brushed its surface, a surge of raw, untamed power coursed through her, a sensation both exhilarating and terrifying. This was no mere enchanted relic; it was a living piece of primordial magic, a fragment of the legendary Heart of Aethel, an artifact whispered to have once sustained an entire forgotten civilization. The Shard hummed with an immense, almost overwhelming energy, far beyond anything the mages of Eldoria had ever encountered, promising a return to their former glory, yet radiating an undeniable, chilling instability.
#
# The Lumina Shard represented Eldoria's last, desperate hope. Its power could undoubtedly revitalize the dying ley lines, restore the kingdom's wards, and bring prosperity back to its people. But its raw, untamed nature presented an equally terrifying risk. The ancient texts Elara had unearthed hinted that the Shard was not merely a source of power, but a conduit—capable of drawing immense magical energy, but also of unleashing catastrophic forces if mishandled or pushed beyond its limits. It could mend the kingdom, or shatter it into dust. Now, Elara, a student barely out of her apprenticeship, found herself holding the fate of Eldoria in her hands, caught between the desperate pleas of her people and the chilling whisper of the Shard's destructive potential. She knew the Arch-Mages would demand its immediate use, but only she had felt its volatile heart, and the terrible choice of salvation or annihilation now rested squarely on her young shoulders.
#
#
# [CHARACTER_AGENT]
# Elara, still reeling from the Shard's intense energy, knew she couldn't keep such a discovery secret for long, yet a deep unease gnawed at her. Her first thought was to seek out Lyra, her closest friend and a fellow student whose pragmatic mind often balanced Elara’s more adventurous spirit. Lyra, with her sharp wit and unwavering loyalty, listened intently as Elara recounted the discovery, her initial skepticism giving way to wide-eyed wonder and then a palpable fear as Elara described the Shard’s volatile hum. "This isn't just power, Elara," Lyra whispered, her voice barely audible, "this feels… hungry. What if the legends are true, and it demands more than it gives?" Her concern for Elara was evident, but beneath it lay a shared, unspoken dread for what this ancient artifact truly portended for their dying world.
#
# The news, however cautiously delivered, inevitably reached Arch-Mage Theron, the Academy's venerable head and a man burdened by Eldoria's slow decay. Theron, his usually stern face etched with years of worry, first dismissed Elara's claims as youthful over-imagination, but the raw magical signature emanating from the carefully shielded Shard quickly dispelled his doubts. A flicker of something akin to religious fervor ignited in his eyes; this was not a danger, but a miracle, a divine intervention. He immediately began planning its integration into Eldoria’s depleted ley lines, envisioning a swift return to prosperity. "This is it, child," he declared, his voice trembling with a mixture of awe and relief, "Eldoria’s salvation. We will harness its might and restore our kingdom to its former glory!" His conviction was absolute, leaving little room for Elara's increasingly urgent warnings about the Shard's inherent instability and the catastrophic risks of mishandling such ancient, untamed power.
#
# The chasm between their viewpoints widened with each passing hour. Theron saw a tool, a solution to be wielded without hesitation, driven by the desperate cries of a dying kingdom. Elara, however, having felt the Shard's raw, untamed heart, understood it as a living entity, capable of both immense creation and utter destruction, a force that demanded respect and profound caution. Lyra, caught between her friend's terrifying discovery and the Arch-Mage's desperate hope, found herself torn, a silent witness to the brewing storm, knowing that the fate of Eldoria now hinged not just on the Shard, but on Elara's courage to defy the very authority she was sworn to obey.
#
#
# [ENDING_AGENT]
# The fateful day arrived, heralded by the solemn tolling of the Academy bells. Arch-Mage Theron, his face a mask of grim determination, prepared to integrate the Lumina Shard into the Grand Nexus, the very heart of Eldoria’s depleted ley lines. Elara watched, a knot of dread tightening in her stomach, as the Shard, now pulsating with an aggressive, almost angry light, was carefully positioned. She knew, with chilling certainty, that this brute-force approach would unleash not salvation, but a cataclysm. As Theron raised his hands, preparing the final incantation, Elara moved. Pushing past startled guards, her eyes locked onto the shimmering artifact. "Stop!" she cried, her voice echoing through the hushed chamber. Ignoring the Arch-Mage’s furious command to stand down, she reached for the Shard, not with a spell of control, but with an intuitive understanding born from her ancient studies and the shared tremor of its power. Lyra, anticipating Elara's desperate act, cast a quick, distracting ward that momentarily disoriented the guards, buying Elara precious seconds.
#
# As Elara's hands closed around the Lumina Shard, a blinding surge of energy erupted, not outward in a destructive wave, but inward, wrapping around her. She didn't try to command it, but to *listen*. She remembered the ancient texts speaking of Aethel's Heart not as a weapon, but as a living pulse, a rhythm to be understood. Instead of forcing its power, she guided it, channeling its raw might through her own being, not into the Grand Nexus directly, but into a more intricate, ancient pattern she had glimpsed in a half-forgotten diagram, a forgotten attunement. The aggressive pulse of the Shard softened, transforming into a steady, resonant hum. A wave of revitalizing magic flowed not just through Eldoria's ley lines, but through the very earth, awakening dormant energies. The withered crops outside began to green, the protective wards around the city solidified, and the air itself shimmered with renewed vitality. Eldoria was saved, not by brute force, but by a young mage's courage and her profound understanding that true power lay not in domination, but in harmony. Arch-Mage Theron, humbled and awestruck, could only watch as the kingdom breathed again, forever changed by the girl who dared to listen to the ancient heart of magic.
#
#
# [PLOT_AGENT]
# As Elara's hands closed around the Lumina Shard, a blinding surge of energy erupted, not outward in a destructive wave, but inward, wrapping around her. She didn't try to command it, but to *listen*. She remembered the ancient texts speaking of Aethel's Heart not as a weapon, but as a living pulse, a rhythm to be understood. Instead of forcing its power, she guided it, channeling its raw might through her own being, not into the Grand Nexus directly, but into a more intricate, ancient pattern she had glimpsed in a half-forgotten diagram, a forgotten attunement. The aggressive pulse of the Shard softened, transforming into a steady, resonant hum. A wave of revitalizing magic flowed not just through Eldoria's ley lines, but through the very earth, awakening dormant energies.
#
# The change was instantaneous and profound. Outside the Academy, the withered crops in the fields visibly began to green, drawing strength from the newly vibrant earth. The protective wards around the city, which had flickered weakly for decades, solidified into shimmering, impenetrable barriers. The very air, once heavy with decay, now shimmered with renewed vitality, carrying the scent of fresh rain and burgeoning life. Arch-Mage Theron, who had been poised to unleash a different kind of power, lowered his hands, his face a mask of profound humility and awe. He saw not a catastrophe, but a miracle, orchestrated by the very student he had dismissed. Eldoria was saved, not by brute force or desperate measures, but by a young mage's courage and her profound understanding that true power lay not in domination, but in harmony with the ancient heart of magic. Lyra rushed to Elara's side, relief washing over her as the Shard, now glowing with a gentle, stable light, settled peacefully in Elara’s grasp, a testament to her profound connection and the kingdom's new dawn.
#
#
# [CHARACTER_AGENT]
# In the days that followed, the transformation of Eldoria was nothing short of miraculous. Rivers ran clearer, forests thickened with vibrant foliage, and the laughter of children, once a rarity, now echoed through the revitalized streets. Elara, no longer just a student, was hailed as the Kingdom’s savior, though she bore the title with a quiet humility. The Lumina Shard, now a steady, gentle beacon, had bonded with her, becoming an extension of her own burgeoning power and understanding. It resided not in a vault, but close to her, a constant reminder of the delicate balance between power and responsibility. Under her guidance, the Academy began to shift its focus, embracing the ancient ways of attunement and harmony that Elara had rediscovered, moving away from the rigid, fading incantations of old.
#
# Arch-Mage Theron, profoundly changed by the events, stepped down from his position as head of the Academy, instead dedicating himself to studying the ancient texts alongside Elara, eager to learn from her intuitive wisdom. He became her most ardent supporter, ensuring her voice was heard in the council of elders, who now looked to her for guidance on matters of magic and the kingdom's future. Lyra, ever the steadfast friend, remained by Elara's side, her pragmatic mind a valuable counterpoint to Elara’s deep magical insights, helping to bridge the gap between ancient wisdom and practical application. Together, they embarked on a new era for Eldoria, one where magic flowed freely, guided not by fear or desperation, but by an understanding that true strength lay in connection, respect, and the delicate dance between humanity and the ancient, living world.
#
# Eldoria, once on the precipice of oblivion, now thrived, a testament to the courage of a young mage who dared to listen when others sought to command. The Lumina Shard, once a symbol of both salvation and destruction, now hummed with the promise of enduring peace, a constant reminder that the greatest power often resided not in force, but in the quiet, profound understanding of the world's intricate heart. Elara, with Lyra at her side and Theron's wisdom to draw upon, knew their journey was far from over. The revitalized kingdom would face new challenges, but with the lessons of the Shard etched into their very being, they were ready to meet them, guided by the harmony she had brought back to Eldoria.
#
# ✨ Story completed!
